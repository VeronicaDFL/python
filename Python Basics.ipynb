# %% [markdown]
# # Intro to Python
# This notebook has some basic Python commands.

# %%
name = "Veronica"
age = 37
awesome = True

# %%
print(name)
# Out:
# Veronica

# %%
def bouncer (age):
    if (age >= 21):
        return "You can drink"
    if (age >= 18):
        return "You can Dance!"
    return "Get Out!"

# %%
bouncer (16)
# Out:
# 'Get Out!'

# %%
bouncer(19)
# Out:
# 'You can Dance!'

# %%
bouncer (37)
# Out:
# 'You can drink'

# %%
for i in range (0,10):
    print("Python is cool!")
# Out:
# Python is cool!
# Python is cool!
# Python is cool!
# Python is cool!
# Python is cool!
# Python is cool!
# Python is cool!
# Python is cool!
# Python is cool!
# Python is cool!

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = pd.DataFrame(np.random.randn(100,4),columns=['A','B','C','D'])

# %%
data.head()
# Out:
#           A         B         C         D
# 0  0.036959  0.543477 -1.503214 -1.932630
# 1  0.094995 -0.846106 -0.769125  0.148259
# 2 -0.561263  0.157561 -1.320123  1.893666
# 3  1.153977  1.418567  2.976068 -1.696822
# 4 -0.370895  0.894179 -0.884990 -0.185168

# %%
data.tail()
# Out:
#            A         B         C         D
# 95  0.067933  0.707237  0.170250 -0.798768
# 96 -0.042294  0.206612  0.012742 -1.537937
# 97 -0.015904  0.372478  0.708577  1.998429
# 98  0.038701 -0.221167 -0.112402  0.997123
# 99 -0.075336 -0.612153  0.015303  0.419208

# %%
plt.scatter(data['A'], data['D'])

# %%
sns.pairplot(data)
